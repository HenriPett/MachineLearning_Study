# %% [markdown]
# <a href="https://colab.research.google.com/github/HenriPett/MachineLearning_Study/blob/main/data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regressão Linear

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Representado pela equação acima, a regressão linear pode ser definida como uma função, que inclui somente duas variáveis (Normalmente, porém não é uma regra) e apresenta uma relação em linha reta entre elas.
# Em um grafico, é posivel notar que as variaveis possuem uma grande descrepância entre eles, sendo possivel dividi-los por uma linha reta.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Parametros que foram utilizados nos modelos exemplo:

# %% [markdown]
# ##  train_test_split()

# %%
x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, train_size= 0.7, random_state=42)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Parametros:
# #### - arrays: Arrays que serão divididos (data_x e data_y).
# #### - test_size: Porcentagem dos dados totais que sera dividido para teste, de 0 a 1.
# #### - train_size: Porcentagem dos dados totais que sera dividido para treino, de 0 a 1 (0.7 ou 70%).
# #### - random_state: Passa um comando para embaralhar os dados aleatoriamente, no exemplo foi usado 42, pois permite, que apesar de rodar o codigo varias vezes ele continuara o mesmo.
# #### - shuffle: Como default = True. Ira embaralhar os dados com o comando do random_state.
# #### - stratify: Caso não seja None, os dados serão divididos para que sejam usados como labels

# %% [markdown]
# ## LinearRegression()

# %%
linear = linear_model.LinearRegression()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Parametros
# #### - fit_intercept: Como default = True. É usado para calcular a interceptação do modelo, caso False, os dados ficarão centralizados.
# #### - normalize: Como default = False. Caso seja True, o dado X sera normalizado antes da regressão. Sera subtraido a média e dividido pela l2-norm (Norma). É recomendado que use a função StandardScaler, ao invez desse parametro.
# #### - copy_X: Como default = True. Copia o dado X, caso falso, o Dado é sobrescrito.
# #### - n_jobs: É usado para especificar quantos processos simultâneos ou threads devem ser usados ​​para rotinas que são paralelizadas. Se usado -1, sera feito o uso de todos os processadores.
# #### - positive: Como default = False. Quanto True, força os coeficientes a serem positivos.

# %% [markdown]
# ## Modelo.fit()

# %%
linear.fit(lindata_x_train, lindata_y_train)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Parametros:
# #### - data: Dados para previsão
# #### - targets: Alvo dos dados, objetivo. Para unsupervised learning, não deve se colocar alvos.

# %% [markdown]
# ## Modelo.predict()

# %%
pred = regress.predict(x_test)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Parametros:
# #### - data: Ira prever, com base nos treinos anteriores do modelo, o dado passado como parametro.

# %% [markdown]
# ## Modelo.score()

# %%
linear.score(lindata_x_test, lindata_y_test)

# %% [markdown]
# ### Parametros:
# #### - data_x: Sera o dado que sera previsto novamente e comparado com o data_y (parametro).
# #### - data_y: Dados usados para comparação e medição da acuracia.

# %% [markdown]
# # Regressão Logistica

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A regressão logística é uma técnica estatística que tem como objetivo produzir, a partir de um conjunto de observações, um modelo que permita a predição de valores tomados por uma variável categórica, frequentemente binária, a partir de uma série de variáveis explicativas contínuas e/ou binárias.
# O modelo logistico é usado normalmente para prever a porcentagem de chance de determinado evento.

# %% [markdown]
# Ex:
# - Na medicina, permite por exemplo determinar os factores que caracterizam um grupo de indivíduos doentes em relação a indivíduos sãos.
# - Em instituições financeiras, pode detectar os grupos de risco para a subscrição de um crédito.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Diferente da regressão linear, onde os dados serão divididos por uma linha reta, a regressão logistica tentara se adaptar aos dados e os dividirá, formando uma linha parecida com um S.

# %% [markdown]
# # SVM

# %% [markdown]
# É um algoritmo de aprendizado de máquina supervisionado que pode ser usado para desafios de classificação ou regressão. Seu foco maior é no treinamento e classificação de um dataset.

# %% [markdown]
# Os “Vetores de suporte” são simplesmente as coordenadas da observação individual. Support Vector Machine é uma fronteira que melhor segrega as duas classes (hiperplano / linha).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Em uma SVM, a questão mais importante é “como podemos identificar o hiperplano?”

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# No exemplo acima, o hiperplano que melhor separa os dados é o B, pois o A comete um erro. Mas em varias classes?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O algoritmo SVM ira separar todas as classes com uma linha reta, como apresentado acima.

# %% [markdown]
# Prós:
# - Funciona muito bem com margem de separação clara.
# - É eficaz nos casos em que o número de dimensões é maior que o número
# de amostras.
# - Ele usa um subconjunto de pontos de treinamento na função de decisão
# (chamados de vetores de suporte), portanto, também é eficiente em
# termos de memória.

# %% [markdown]
# Contras:
# - Não tem um bom desempenho quando temos um grande conjunto de
# dados porque o tempo de treinamento necessário é grande.
# - Ele também não funciona muito bem quando o conjunto de dados tem
# mais ruído, ou seja, as classes de destino estão sobrepostas.

# %% [markdown]
# # CNN

# %% [markdown]
# Uma Rede Neural Convolucional (CNN/ConvNet), é um algoritmo de Aprendizado Profundo que pode captar uma imagem de entrada, atribuir importância (pesos e vieses que podem ser aprendidos) a vários aspectos / objetos da imagem e ser capaz de diferenciar um do outro. A arquitetura de uma ConvNet é análoga àquela do padrão de conectividade de neurônios no cérebro humano. A CNN é interessante pois ela é treinada e atualiza os pesos dos neuronios a cada convulação, portando, aumentando sua acuracia.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Uma convolução é a aplicação simples de um filtro a uma entrada que resulta em uma ativação. A inovação de redes neurais convolucionais é a capacidade de aprender automaticamente um grande número de filtros em paralelo específico a um conjunto de dados de treinamento sob as restrições de um problema específico de modelagem preditiva, como a classificação de imagens. O resultado são recursos altamente específicos que podem ser detectados em qualquer lugar nas imagens de entrada.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O principal uso da CNN é a classificação de imagens por meio dos treinos, como apresentado acima, sendo usado datasets gigantes com varias imagens diferentes.

# %% [markdown]
# ## Função de ativação:

# %% [markdown]
# As funções de ativação servem para trazer a não-linearidades ao sistema, para que a rede consiga aprender qualquer tipo de funcionalidade. Há muitas funções, como sigmoid, tanh e softmax, mas a mais indicada para redes convolucionais é a Relu por ser mais eficiente computacionalmente sem grandes diferenças de acurácia quando comparada a outras funções. Essa função zera todos os valores negativos da saída da camada anterior.

# %% [markdown]
# ## Função Relu?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A função ReLU é não linear, o que significa que podemos facilmente copiar os erros para trás e ter várias camadas de neurônios ativados pela função ReLU.
#
# A principal vantagem de usar a função ReLU sobre outras funções de ativação é que ela não ativa todos os neurônios ao mesmo tempo. O que isto significa ? Se você olhar para a função ReLU e a entrada for negativa, ela será convertida em zero e o neurônio não será ativado. Isso significa que, ao mesmo tempo, apenas alguns neurônios são ativados, tornando a rede esparsa e eficiente e fácil para a computação.

# %% [markdown]
# ## Função Softmax

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A função softmax transforma as saídas para cada classe para valores entre 0 e 1 e também divide pela soma das saídas. Isso essencialmente dá a probabilidade de a entrada estar em uma determinada classe.
#
# É idealmente usada na camada de saída do classificador, onde realmente estamos tentando gerar as probabilidades para definir a classe de cada entrada.

# %% [markdown]
# ## Pooling

# %% [markdown]
# Uma camada de pooling serve para simplificar a informação da camada anterior. Assim como na convolução, é escolhida uma unidade de área, por exemplo 2x2, para transitar por toda a saída da camada anterior. A unidade é responsável por resumir a informação daquela área em um único valor. Se a saída da camada anterior for 24x24, a saída do pooling será 12x12.
#
# Além disso, é preciso escolher como será feita a sumarização. O método mais utilizado é o maxpooling, no qual apenas o maior número da unidade é passado para a saída. Essa sumarização de dados serve para diminuir a quantidade de pesos a serem aprendidos e também para evitar overfitting.

# %% [markdown]
# ## Flatten

# %% [markdown]
# Ela basicamente opera uma transformação na matrix da imagem, alterando seu formato para um array. Por exemplo, uma imagem em grayscale de 28x28 será transformada para um array de 784 posições. Ela "amassa" o dado e diminui o numero de diensões do array.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Exemplo geral:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Normalização e padronização de dados

# %% [markdown]
# A transformação dos seus dados, que já estão tratados, é uma pratica para evitar que seu algoritmo fique enviesado para as variáveis com maior ordem de grandeza.
#
# O pré-processamento dos dados é necessaria para valores mais altos, que não necessariamente são mais relevantes, não influenciarem no treino dos modelos.
#
# As duas técnicas tem o mesmo objetivo: transformar todas as variáveis na mesma ordem de grandeza. E a diferença básica é que padronizar as variáveis irá resultar em uma média igual a 0 e um desvio padrão igual a 1. Já normalizar tem como objetivo colocar as variáveis dentro do intervalo de 0 e 1, caso tenha resultado negativo -1 e 1.

# %% [markdown]
# Padronizar:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Normalizar:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# No Python (Sklearn), as funções MinMaxScaler() e Normalizer(), são usadas para normalizar os dados
#
# MinMaxScaler():

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))
scaled_data = scaler.fit_transformer(data)

# %% [markdown]
# O parâmetro feature_range= (0,1) é o default que resultará a normalização variando entre 0 e 1.

# %% [markdown]
# Normalizer():

# %%
from sklearn.preprocessing import Normalizer

transformer = Normalizer(norm='11'). fit(data)

transformer = Normalizer(norm='12'). fit(data)

# %% [markdown]
# O parâmetro norm='12', que é o default, usa a distância Euclidiana, uma outra alternativa é utilizar a distância Manhattan, norm="11".
#
# De forma simples, uma maneira de exemplificar o momento mais adequado em se utilizar cada uma delas é pensar e uma distância entre dois pontos em uma cidade.  Se é um trajeto de um pássaro, a distância euclidiana é mais conveniente já que pode traçar uma diagonal de um ponto para o outro. Agora, se pensarmos que esses pontos serão percorridos por um humano ou carro que precisa respeitar as ruas e quarteirões o uso da distância Manhattan é mais adequada .

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# O transfer learning é usar um modelo pré-treinado, porém para outro proposito o qual foi previamente definido. É a reutilização de um modelo, para um novo problema. Isto é, vou usar uma rede neural treinada em outro outro conjunto de dados, geralmente maior, para resolver um novo problema.

# %% [markdown]
# O segredo é treinar o seu modelo em um modelo pré-treinado, para conseguir uma acuracia melhor do que o comum.
#
# Fine tunning é o nome dessa técnica, onde atualiza os pesos do modelo pré-treinado, adicionando novas "epócas" (epochs) com uma diferente tarefa.
#
# Caso seja feito um fine tunning na resnet (que contem inumeras imagens aleatórias de varios objetos), por exemplo, com mais imagens de gatos. O modelo ficará melhor em identificar gatos, porém pior em identificar outras coisas, pois ele acabou "esquecendo" um pouco das outras imagens. Uma boa solução para esse problema é, continuar implementando imagens aleatórias (ao invez de só gatos), porem em menor quantidade.

# %% [markdown]
# # Avaliação de modelo

# %% [markdown]
# Uma das formas de avaliação de um modelo classiicador binario é a Curva Característica de Operação do Receptor (COR ou ROC), que avalia o desempenho do modelo a medida que o seu limiar de discriminação varia

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Como apresentado na imagem, um classificador "perfeito" não é bom, pois em dados diferentes pode haver erros relevantes. Um modelo considerado "bom" é o que se mantem na curva COR e está posicionado na posição mais alta, sendo em torno de 93% e 98%.

# %% [markdown]
# # Métricas de avaliação

# %% [markdown]
# ## Acurácia

# %% [markdown]
#  A mais comum, métrica utilizada para visualizar de forma geral o desempenho do classificador. Fornece o percentual de classificações corretas pelo classificador.
#
# Possui um problema com classes desbalanceadas. Por exemplo, ao passar no conjunto de treino muitos dados de uma mesma classe, o classificador ficará bom em determinar aquela especifica classe, porem ruim em determinar outras.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import accuracy_score # importando a biblioteca para calcular a acurácia
acuracia = accuracy_score(y_teste, resultado_knn)
print('Acurácia: %f' % acuracia)

# %% [markdown]
# ## Precisão

# %% [markdown]
# Fornece o numero de vezes que uma determinada classe foi predita corretamente dividido pelo numero de vezes que a classe foi predita.
#
# A precisão, diferente da acurácia, avalia o modelo por classes, trazendo detalhadamente a porcentagem de acerto nas predições com base em cada classe, assim, evitando a falta de acertividade ocorrida na acurácia.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import precision_score #precision
precision = precision_score(y_teste, resultado_knn)
print('Precision: %f' % precision)

# %% [markdown]
# ## Revocação

# %% [markdown]
# Fornece o numero de vezes que uma determinada classe foi predita corretamente dividido pelo numero da classe que contem no dado.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import recall_score #recall
recall = recall_score(y_teste, resultado_knn)
print('Recall: %f' % recall).

# %% [markdown]
# ## Medida F1

# %% [markdown]
# É uma medida que correlaciona a precisão e a revocação.
#
# Por ser uma combinação das duas metricas anteriores, é considerada um indicador preciso e que nos da uma informação relevante em apenas um numero.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import f1_score #f1-score
f1 = f1_score(y_teste, resultado_knn)
print('F1-Score: %f' % f1)

# %% [markdown]
# # Dropout

# %% [markdown]
# Dropout é uma técnica radicalmente diferente para regularização. O Dropout não depende da modificação da função de custo. Em vez disso, no Dropout, modificamos a própria rede.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Acima, vemos uma rede neural com 3 inputs e dois outputs de forma natural. Ao aplicar o Dropout, certos neuronios da camada "escondida" vão aleatóriamente ser retirados. Como apresentado na imagem seguinte.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Com esse procedimento, a rede classificara os pesos e vieses, sem a presença de determinados neuronios. Quando abandonamos diferentes conjuntos de neurônios, é como se estivéssemos treinando redes neurais diferentes. E assim, o procedimento de eliminação é como calcular a média dos efeitos de um grande número de redes diferentes. As diferentes redes se adaptarão de diferentes maneiras, e assim, esperançosamente, o efeito líquido do Dropout será reduzir o overfitting.
